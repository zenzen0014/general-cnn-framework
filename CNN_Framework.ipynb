# %% [markdown]
# # Framework CNN PyTorch Sederhana
#
# Notebook ini hanya menjadi antarmuka sederhana. Konfigurasi utama ada di `config.py`.

# %% [markdown]
# ![CNN Workflow](cnn-framework-representation.png)

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 1)) (2.7.0)
# Requirement already satisfied: torchvision in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 2)) (0.22.1)
# Requirement already satisfied: numpy in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: matplotlib in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 4)) (3.10.8)
# Requirement already satisfied: pillow in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 5)) (12.1.1)
# Requirement already satisfied: scikit-learn in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: kagglehub in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: python-dotenv in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: dotenv in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 9)) (0.9.9)
# Requirement already satisfied: torchview in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 10)) (0.2.7)
# Requirement already satisfied: graphviz in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from -r requirements.txt (line 11)) (0.21)
# Requirement already satisfied: filelock in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from torch->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from torch->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from torch->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from torch->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from torch->-r requirements.txt (line 1)) (2026.1.0)
# Requirement already satisfied: setuptools in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from torch->-r requirements.txt (line 1)) (80.10.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from scikit-learn->-r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from kagglehub->-r requirements.txt (line 7)) (0.1.23)
# Requirement already satisfied: pyyaml in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from kagglehub->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: requests in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from kagglehub->-r requirements.txt (line 7)) (2.32.5)
# Requirement already satisfied: tqdm in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from kagglehub->-r requirements.txt (line 7)) (4.67.3)
# Requirement already satisfied: protobuf in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub->-r requirements.txt (line 7)) (6.33.0)
# Requirement already satisfied: six>=1.5 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from jinja2->torch->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from requests->kagglehub->-r requirements.txt (line 7)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from requests->kagglehub->-r requirements.txt (line 7)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from requests->kagglehub->-r requirements.txt (line 7)) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from requests->kagglehub->-r requirements.txt (line 7)) (2026.1.4)
# Requirement already satisfied: colorama in C:\Users\zendi\anaconda3\envs\DeepLearning\Lib\site-packages (from tqdm->kagglehub->-r requirements.txt (line 7)) (0.4.6)

# %% [markdown]
# ## 1. Cek Konfigurasi
#
# Ubah pengaturan eksperimen di `config.py`, kemudian jalankan cell berikut.

# %%
from config import CONFIG

CONFIG.validate()
CONFIG
# Out:
# Config(sumber_dataset='folder_lokal', dataset_root='./dataset', dataset_name='banana_ripeness', folder_lokal='./dataset/banana_ripeness', kaggle_dataset='barkataliarbab/banana-ripeness-classification-classification', kaggle_cache_dir='./dataset/_kaggle_cache', allow_kaggle_download=False, max_per_class=200, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15, image_size=224, augment_train=True, image_channels=3, batch_size=32, epochs=30, learning_rate=0.001, weight_decay=0.0, num_workers=2, device='auto', early_stopping=True, early_stopping_patience=5, early_stopping_min_delta=0.001, early_stopping_monitor='val_loss', model_name='simple_cnn', pretrained=False, freeze_backbone=False, dropout=0.5, output_dir='outputs', model_filename='best_model.pth', seed=42)

# %% [markdown]
# ## 2. Training
#
# Cell ini menjalankan proses training penuh.

# %%
import train

train.main()
# Out:
# ======================================================================
# 1. Menyiapkan Dataset
# ======================================================================
# Mode dataset        : folder_lokal
# Dataset aktif       : banana_ripeness
# Path dataset lokal  : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\dataset\banana_ripeness
# Folder kelas terbaca: C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\dataset\banana_ripeness
# Folder dataset : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\dataset\banana_ripeness
# Nama kelas     : ['overripe', 'ripe', 'rotten', 'unripe']
# Total gambar   : 800
# Distribusi     : train=560, val=120, test=120
#
# ======================================================================
# 2. Membuat Model
# ======================================================================
# Model              : simple_cnn
# Pretrained         : False
# Device             : cuda
# Total parameter    : 422,788
# Trainable parameter: 422,788
#
# Trainable Parameter Table
# ================================================================================
#          Layer Name            Shape Parameters Trainable
# features.0.0.weight    [32, 3, 3, 3]        864       Yes
#   features.0.0.bias             [32]         32       Yes
# features.0.1.weight             [32]         32       Yes
#   features.0.1.bias             [32]         32       Yes
# features.2.0.weight   [64, 32, 3, 3]     18,432       Yes
#   features.2.0.bias             [64]         64       Yes
# features.2.1.weight             [64]         64       Yes
#   features.2.1.bias             [64]         64       Yes
# features.4.0.weight  [128, 64, 3, 3]     73,728       Yes
#   features.4.0.bias            [128]        128       Yes
# features.4.1.weight            [128]        128       Yes
#   features.4.1.bias            [128]        128       Yes
# features.6.0.weight [256, 128, 3, 3]    294,912       Yes
#   features.6.0.bias            [256]        256       Yes
# features.6.1.weight            [256]        256       Yes
#   features.6.1.bias            [256]        256       Yes
# classifier.2.weight       [128, 256]     32,768       Yes
#   classifier.2.bias            [128]        128       Yes
# classifier.5.weight         [4, 128]        512       Yes
#   classifier.5.bias              [4]          4       Yes
#
# Parameter Summary
# ================================================================================
# Total parameter     : 422,788
# Trainable parameter : 422,788
# Frozen parameter    : 0
# Trainable ratio     : 100.00%
# Parameter table CSV : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\trainable_parameter_table.csv
# Parameter table PNG : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\trainable_parameter_table.png
# Architecture TXT    : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\model_architecture.txt
# Architecture PNG    : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\model_architecture.png
# (process:18692): Pango-WARNING **: 21:42:47.535: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.
# Architecture graph : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\simple_cnn_architecture.png
#
# ======================================================================
# 3. Training
# ======================================================================
# Model dilatih maksimal sebanyak: 30 epochs
# Model terbaik akan disimpan di: C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\best_model.pth
# Early stopping       : aktif
# Monitor              : val_loss
# Patience             : 5
# Minimum delta        : 0.001
#
# Epoch | Train Loss | Train Acc | Val Loss | Val Acc |   Early Stop
# ----------------------------------------------------------------------------------
#     1 |     1.0546 |    58.57% |   0.8671 |  80.00% |          0/5 *best
#     2 |     0.6410 |    78.21% |   0.6241 |  75.83% |          0/5
#     3 |     0.5260 |    82.50% |   0.7271 |  70.00% |          1/5
#     4 |     0.4803 |    82.14% |   0.5415 |  80.83% |          0/5 *best
#     5 |     0.5112 |    79.29% |   0.4906 |  81.67% |          0/5 *best
#     6 |     0.4237 |    83.39% |   0.4475 |  85.83% |          0/5 *best
#     7 |     0.4033 |    85.18% |   0.4409 |  87.50% |          0/5 *best
#     8 |     0.3716 |    86.25% |   0.4444 |  85.83% |          1/5
#     9 |     0.3963 |    86.79% |   0.4993 |  85.00% |          2/5
#    10 |     0.4032 |    87.50% |   0.3833 |  86.67% |          0/5
#    11 |     0.4075 |    84.64% |   0.4361 |  86.67% |          1/5
#    12 |     0.3750 |    86.25% |   0.3981 |  88.33% |          2/5 *best
#    13 |     0.3648 |    88.04% |   0.6071 |  79.17% |          3/5
#    14 |     0.3367 |    86.96% |   0.3434 |  90.00% |          0/5 *best
#    15 |     0.3331 |    86.43% |   0.3751 |  90.00% |          1/5
#    16 |     0.3061 |    88.39% |   0.5540 |  81.67% |          2/5
#    17 |     0.3422 |    87.50% |   0.4133 |  87.50% |          3/5
#    18 |     0.2982 |    89.29% |   0.5627 |  85.00% |          4/5
#    19 |     0.3007 |    89.64% |   0.5224 |  83.33% |         STOP
#
# Early stopping aktif pada epoch 19. Training dihentikan karena val_loss tidak membaik selama 5 epoch.
#
# ======================================================================
# 4. Ringkasan
# ======================================================================
# Best validation accuracy : 90.00%
# Model terbaik            : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\best_model.pth
# History training         : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\training_history.json
# Grafik training          : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\training_curve.png

# %% [markdown]
# ## 3. Evaluasi Test Set
#
# Jalankan setelah training selesai.

# %%
import evaluate

evaluate.main()
# Out:
# ======================================================================
# 1. Menyiapkan Test Set
# ======================================================================
# Mode dataset        : folder_lokal
# Dataset aktif       : banana_ripeness
# Path dataset lokal  : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\dataset\banana_ripeness
# Folder kelas terbaca: C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\dataset\banana_ripeness
# Folder dataset : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\dataset\banana_ripeness
# Nama kelas     : ['overripe', 'ripe', 'rotten', 'unripe']
# Jumlah test    : 120
#
# ======================================================================
# 2. Memuat Model Terbaik
# ======================================================================
# Model dimuat dari       : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\best_model.pth
# Best validation accuracy: 90.00%
#
# ======================================================================
# 3. Evaluasi Test Set
# ======================================================================
# Test accuracy: 87.50%
#
#               precision    recall  f1-score   support
#
#     overripe     0.8462    0.8800    0.8627        25
#         ripe     0.9333    0.8750    0.9032        32
#       rotten     0.8333    0.7576    0.7937        33
#       unripe     0.8824    1.0000    0.9375        30
#
#     accuracy                         0.8750       120
#    macro avg     0.8738    0.8781    0.8743       120
# weighted avg     0.8749    0.8750    0.8732       120
#
#
# ======================================================================
# 4. Output Evaluasi
# ======================================================================
# Report          : C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\test_report.txt
# Confusion matrix: C:\Users\zendi\Documents\DeepLearning\Pengolahan Citra Digital\Classification CNN - Own Model\outputs\confusion_matrix_test.png

# %% [markdown]
# ## 4. Membaca Grafik
#
# - Jika `train_loss` turun dan `val_loss` juga turun, model belajar dengan baik.
# - Jika `train_acc` tinggi tetapi `val_acc` rendah, kemungkinan overfitting.
# - Jika semua akurasi rendah, coba tambah data, perbaiki augmentasi, atau gunakan pretrained model.
# - Confusion matrix menunjukkan kelas mana yang sering salah diprediksi.
